# %%
import numpy as np
from datetime import datetime as dt
import pandas as pd, datetime as dt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
cd C:\Users\USER\OneDrive\Documents\GitHub\Datacracy_scala_hackathon\data
# Out:
# C:\Users\USER\OneDrive\Documents\GitHub\Datacracy_scala_hackathon\data

# %%
user = pd.read_csv('user_processed.csv',sep=',')
listening = pd.read_csv('listening_processed.csv',sep=',')
order = pd.read_csv('order_processed.csv',sep=',')
clustering = pd.read_csv('clustering_processed.csv',sep=',')

# %% [markdown]
# # # Processing data

# %%
# change column name
order = order.rename(columns = {"OrderID (PK)": "orderID", "Transaction Date" : "transaction_date","UserID (FK)" : "userID", "Bill Type": "bill_type", "Total Amount": "total_amount" })
clustering = clustering.rename(columns = {"User_ID (FK)": "userID", "Type_user": "type_user", "MainCluster_ID" : "main_cluseringID", "MainCluster_Description" : "main_clustering_description"})
listening = listening.rename(columns = {"PlaylistID (PK)": "playlistID", "Playlist Name":"playlist_name", "Category":"cat", "Sub Category" :"sub_cat", "Playlist Type" :"palylist_type","Playlist Duration (min)": "playlist_duration","Actual Duration (min)":"actual_duation","UserID (FK)":"userID", "Listening Time":"listening_time", "Listening Date" :"listening_date", "Listening Datetime":"listening_datetime"})
user = user.rename(columns = {"UserID (PK)":"userID", "VIP hay Free":"user_type", "Gender":"gender", "Year of Birth":"year_of_birth","Age Range": "age_range", "Age":"age", "Region": "region","Operation Systems":"operation_system","Registration Date":"registration_date", "Total Listerning":"total_listening", "Total Listening Time (Min)":"total_listening_time",   })

# change date time
# xu li datetime
order.transaction_date = pd.to_datetime(order['transaction_date'], format='%Y-%m-%d')
user.registration_date = pd.to_datetime(user['registration_date'], format='%Y-%m-%d')
listening.listening_datetime = pd.to_datetime(listening['listening_datetime'], format='%Y-%m-%d')

# change date by weekly
def adding_by_week(df, date_field):
    # df["by_week"] = df[[date_field]].copy()
    # df.resample('W-Mon', on=date_field).sum().reset_index().sort_values(by=date_field)
    # order1.resample('W-Mon', on='transaction_date').sum().reset_index().sort_values(by='transaction_date')
    df['by_week'] = df.apply(lambda row: row[date_field] - dt.timedelta(days=row[date_field].weekday()), axis=1)
    df = df['by_week'].groupby(df['by_week']).count()

adding_by_week(order, "transaction_date")
adding_by_week(user, "registration_date")
adding_by_week(listening, "listening_datetime")

# %%
## fillna for the user Table

user.operation_system = user.operation_system.fillna('none')
user["gender"] = user.gender.replace("no information","none")
user["gender"] = user.gender.replace("other","none")

## add some features related to time of the listening Table

listening['hour_listening'] = listening.listening_datetime.dt.hour
listening['dayofweek'] = listening['listening_datetime'].dt.dayofweek

listening["timepoint_of_the_day"] = listening.hour_listening.apply(lambda x : 
                                                             "late night" if x < 4 else
                                                             "early morning" if x < 7 else
                                                             "morning" if x < 11 else
                                                             "early afternoon" if x < 16 else
                                                             "afternoon" if x < 18 else
                                                             "evening"
                                                            )

listening['dayofweek'] =listening.dayofweek.apply(lambda x :  "Mon" if x == 0 else
                                                             "Tue" if x ==1 else
                                                             "Wed" if x ==2 else
                                                             "Thu" if x == 3 else
                                                             "Fri" if x == 4 else
                                                             "Sat" if x == 5 else
                                                             "Sun" 
                                                            )

listening['Workingday'] = listening["dayofweek"].apply(lambda x : 0 if x == 'Sun' or x == 'Sat' else 1)

# %% [markdown]
# ### Tập trung phân tích nhóm paid user - high value (tăng độ engagement)
# - Kèm theo 1 con số dẫn chứng của Mckegin XXX về việc giữ chân khách hàng cũ
# - Process tập data lại dựa trên 3 nhóm này thôi

# %%
# chuyển qua dùng tập paid
user.head(3)
# Out:
#    userID user_type gender  year_of_birth       age_range   age region  \
# 0   86229      free   male            NaN  No information   NaN     VN
# 1   48053      free   male         1995.0         25 - 34  26.0     VN
# 2   46340      free   male         1988.0         25 - 34  33.0     VN
#
#   operation_system registration_date  total_listening  total_listening_time  \
# 0          android        2020-11-27              218                4151.3
# 1              ios        2020-08-24               19                 278.6
# 2          website        2020-08-19               28                 170.5
#
#      by_week
# 0 2020-11-23
# 1 2020-08-24
# 2 2020-08-17

# %%
user_money = pd.merge(user,total_amount, how='left',left_on='userID', right_on='userID')
total = pd.merge(clustering,user_money, how='left',left_on='userID', right_on='userID')
total.head()
# Out:
#    userID type_user  main_cluseringID main_clustering_description user_type  \
# 0   40834      free                 1                 Hibernating      free
# 1   40854      free                 1                 Hibernating      free
# 2   40876      free                 1                 Hibernating      free
# 3   40883      free                 1                 Hibernating      free
# 4   40891      free                 1                 Hibernating      free
#
#            gender  year_of_birth       age_range   age region  \
# 0  no information            NaN  No information   NaN     QT
# 1          female         1999.0         18 - 24  22.0     VN
# 2  no information            NaN  No information   NaN     VN
# 3  no information            NaN  No information   NaN     VN
# 4  no information            NaN  No information   NaN     VN
#
#   operation_system registration_date  total_listening  total_listening_time  \
# 0              ios        2020-07-01                2                   8.7
# 1          website        2020-07-01              444               20988.0
# 2              ios        2020-07-01                3                   0.8
# 3              ios        2020-07-01                5                   2.9
# 4              ios        2020-07-01               13                  71.5
#
#      by_week  oderID  total_amount
# 0 2020-06-29     NaN           NaN
# 1 2020-06-29     NaN           NaN
# 2 2020-06-29     NaN           NaN
# 3 2020-06-29     NaN           NaN
# 4 2020-06-29     NaN           NaN

# %%
paid_user = clustering[clustering.type_user == 'paid']
list_hv_paid = ['Loyal Users','Potential Users','New Paid Users']
hv_paid = paid_user.loc[paid_user.main_clustering_description.isin(list_hv_paid)]
hv_paid
# Out:
#        userID type_user  main_cluseringID main_clustering_description
# 24820   40843      paid                 5              New Paid Users
# 24821   41955      paid                 5              New Paid Users
# 24822   44112      paid                 5              New Paid Users
# 24823   45239      paid                 5              New Paid Users
# 24824   45647      paid                 5              New Paid Users
# ...       ...       ...               ...                         ...
# 27447   98716      paid                 7                 Loyal Users
# 27448  101492      paid                 7                 Loyal Users
# 27449  102073      paid                 7                 Loyal Users
# 27450  103669      paid                 7                 Loyal Users
# 27451  106406      paid                 7                 Loyal Users
#
# [1703 rows x 4 columns]

# %%
listening.describe()
# Out:
#           playlistID  playlist_duration  actual_duation         userID  \
# count  750098.000000      750098.000000   750098.000000  750098.000000
# mean     4586.328209         565.726017       15.428639   68396.183116
# std       346.636915        1339.030831       26.597340   17995.910718
# min      3808.000000           1.300000        0.000000   40834.000000
# 25%      4387.000000         135.300000        1.300000   52016.000000
# 50%      4619.000000         291.300000        7.300000   66782.000000
# 75%      4827.000000         464.400000       19.400000   82996.000000
# max      5440.000000       13971.900000     1769.600000  107219.000000
#
#        Unnamed: 11
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %% [markdown]
# ## User cases:
# Dựa trên đầu sách đã đọc gần nhất => recommend đầu sách tiếp theo cho ng đó
# Các cách làm
# 1. Input là userID (thuộc high value paid user)
# 2. Cho ra nhóm cluster mà user này thuộc - cho ra cuốn sách cuối cùng mà user này nghe
# 3. Cho ra bảng thông tin liên quan về các loại sách với nhau
# 4. Từ cuốn sách cuối cùng mà ng này đọc - recommend cho cuốn sách có lift cao tương tự

# %% [markdown]
# ### tạo các bảng market basket
# Các bước cần làm,
# làm trước cho total table sau đó làm riêng cho từng cluster
# - tạo dòng đơn hàng và sản phẩm (row là userID, column là playlist)
# - biến giá trị thành 0 và 1
# - lọc ra những ng nghe từ 2 cuốn trở lên
# - ra table frequently (để ra support của mỗi cuốn sách)
# - tính ra bảng mỗi liên hệ giữa các sản phẩm với nhau

# %%
# Chỉ quan tâm đến có nghe thiệt không chứ không phải bấm lộn, time >= 3 
def encode_time(x):
    if x>=3:
        return x
    else:
        return 0

# Chỉ quan tâm đến có nghe hay không, encode data => có nghe = 1
def encode(x):
    if x>0:
        return 1
    else:
        return 0
    
def mb_frequent(df,list_userid,min_sup = 0.1):
#     dùng df sau khi đã được lọc thành 0,1 và có từ 2 playlist trở lên
    df = df[df.index.isin(list_userid)]
    frequent = apriori(df, min_support = min_sup,
                        use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)
    frequent['length'] = frequent['itemsets'].apply(lambda x:len(x))
    return frequent

# %%
# biến thành bảng basket_table trước, sau đó lọc paid user ra
basket = listening.groupby(['userID','playlist_name'])['actual_duation'].sum().unstack().reset_index().fillna(0).set_index('userID')
# quan tâm đến nghe thực >3
basket = basket.applymap(encode_time) 
# biến thành nghe và không nghe 0 và 1
basket = basket.applymap(encode)
# chỉ lấy user nào nghe từ 2 nhóm trở lên
basket = basket[(basket >0).sum(axis=1) >=2]
basket
# Out:
# playlist_name   Bé Gấu 5 Tuổi Đã Dạy Tôi Những Gì   Kinh Vu Lan Bồn  \
# userID
# 40839                                           0                 0
# 40840                                           0                 0
# 40842                                           0                 0
# 40843                                           0                 0
# 40844                                           0                 0
# ...                                           ...               ...
# 107068                                          0                 0
# 107120                                          0                 0
# 107121                                          0                 0
# 107129                                          0                 0
# 107176                                          0                 0
#
# playlist_name   Triết - 101 Đoá Sen   Triết - Trí Tuệ Hoan Hỷ  \
# userID
# 40839                             0                         0
# 40840                             0                         0
# 40842                             0                         0
# 40843                             0                         0
# 40844                             0                         0
# ...                             ...                       ...
# 107068                            0                         0
# 107120                            0                         0
# 107121                            0                         0
# 107129                            0                         0
# 107176                            0                         0
#
# playlist_name   Triết - Đức Phật Thuyết Giảng Về Tánh Không Và Vô Ngã  \
# userID
# 40839                                                          0
# 40840                                                          0
# 40842                                                          0
# 40843                                                          0
# 40844                                                          0
# ...                                                          ...
# 107068                                                         0
# 107120                                                         0
# 107121                                                         0
# 107129                                                         0
# 107176                                                         0
#
# playlist_name   Đồng Dao Cho Bé 2   Đồng Dao Cho Bé 3  "Phúc" Nuôi Dạy Con  \
# userID
# 40839                           0                   0                    0
# 40840                           0                   0                    0
# 40842                           0                   0                    0
# 40843                           0                   0                    0
# 40844                           0                   0                    0
# ...                           ...                 ...                  ...
# 107068                          0                   0                    0
# 107120                          0                   0                    0
# 107121                          0                   0                    0
# 107129                          0                   0                    0
# 107176                          0                   0                    0
#
# playlist_name  #HOHATUTA Học hành và trưởng thành cùng Hà Anh  \
# userID
# 40839                                                       0
# 40840                                                       1
# 40842                                                       0
# 40843                                                       0
# 40844                                                       0
# ...                                                       ...
# 107068                                                      0
# 107120                                                      0
# 107121                                                      0
# 107129                                                      0
# 107176                                                      0
#
# playlist_name  10 Bí Quyết Của Các MC, Diễn Giả  ...  \
# userID                                           ...
# 40839                                         0  ...
# 40840                                         0  ...
# 40842                                         0  ...
# 40843                                         0  ...
# 40844                                         0  ...
# ...                                         ...  ...
# 107068                                        0  ...
# 107120                                        0  ...
# 107121                                        0  ...
# 107129                                        0  ...
# 107176                                        0  ...
#
# playlist_name  Độc Đáo TV - Tin tức hàng ngày  \
# userID
# 40839                                       0
# 40840                                       0
# 40842                                       0
# 40843                                       0
# 40844                                       0
# ...                                       ...
# 107068                                      0
# 107120                                      0
# 107121                                      0
# 107129                                      0
# 107176                                      0
#
# playlist_name  Đội Thiếu Niên Du Kích Thành Huế  \
# userID
# 40839                                         0
# 40840                                         0
# 40842                                         0
# 40843                                         0
# 40844                                         0
# ...                                         ...
# 107068                                        0
# 107120                                        0
# 107121                                        0
# 107129                                        0
# 107176                                        0
#
# playlist_name  Đội Thiếu Niên Du Kích Đình Bảng  \
# userID
# 40839                                         0
# 40840                                         0
# 40842                                         0
# 40843                                         0
# 40844                                         0
# ...                                         ...
# 107068                                        0
# 107120                                        0
# 107121                                        0
# 107129                                        0
# 107176                                        0
#
# playlist_name  Đội Thiếu Niên Tình Báo Bát Sắt  Đột Phá Tư Duy Thương Hiệu  \
# userID
# 40839                                        0                           0
# 40840                                        0                           0
# 40842                                        0                           0
# 40843                                        0                           0
# 40844                                        0                           0
# ...                                        ...                         ...
# 107068                                       0                           0
# 107120                                       0                           0
# 107121                                       0                           0
# 107129                                       0                           0
# 107176                                       0                           0
#
# playlist_name  Đừng Bao Giờ Từ Bỏ Ước Mơ  Đừng Mơ Sói Ạ !  Đừng để mất bò  \
# userID
# 40839                                  0                0               0
# 40840                                  0                0               0
# 40842                                  0                0               0
# 40843                                  0                0               0
# 40844                                  0                0               0
# ...                                  ...              ...             ...
# 107068                                 0                0               0
# 107120                                 0                0               0
# 107121                                 0                0               0
# 107129                                 0                0               0
# 107176                                 0                0               0
#
# playlist_name  Ưu Đãi Đặc Biệt  Ứng Dụng Thành Công NLP
# userID
# 40839                        0                        0
# 40840                        0                        0
# 40842                        0                        0
# 40843                        0                        0
# 40844                        0                        0
# ...                        ...                      ...
# 107068                       0                        0
# 107120                       0                        0
# 107121                       0                        0
# 107129                       0                        0
# 107176                       0                        0
#
# [13733 rows x 1280 columns]

# %%
# list_userid = list(hv_paid[hv_paid.main_clustering_description == cluster].userID)

# %%
def get_list(df,value,col):
    list_userid = list(df[df[col] == value]['userID'])
    return list_userid

# %%
order.head()
# Out:
#    orderID transaction_date  userID bill_type  total_amount    by_week
# 0     6706       2020-08-16   44822       VIP        199000 2020-08-10
# 1     6998       2020-08-23   47128       VIP        199000 2020-08-17
# 2     6927       2020-08-21   47134       VIP        199000 2020-08-17
# 3     7054       2020-08-25   45972       VIP        199000 2020-08-24
# 4     6929       2020-08-21   43556       VIP        199000 2020-08-17

# %%
set(order.bill_type)
# Out:
# {'9K', 'VIP', 'XU'}

# %%
list_userid = get_list(order,'XU','bill_type')
new_frequent = mb_frequent(basket,list_userid,min_sup = 0.1)
new_frequent
# Out:
#     support                                           itemsets  length
# 0  0.668203                      (Muôn Kiếp Nhân Sinh - Tập 1)       1
# 1  0.211982                        (Hành Trình Về Phương Đông)       1
# 2  0.193548  (Hành Trình Về Phương Đông, Muôn Kiếp Nhân Sin...       2
# 3  0.179724                                     (Đắc Nhân Tâm)       1
# 4  0.124424                                (Dấu Chân Trên Cát)       1
# 5  0.119816                    (Thái độ quyết định thành công)       1
# 6  0.115207   (Dấu Chân Trên Cát, Muôn Kiếp Nhân Sinh - Tập 1)       2
# 7  0.110599                        (Minh Triết Trong Đời Sống)       1
# 8  0.101382                  (Trời Tính Không Bằng Trời Tính )       1

# %%
list_userid2 = get_list(order,'9K','bill_type')
new_frequent2 = mb_frequent(basket,list_userid2,min_sup = 0.1)
new_frequent2
# Out:
#     support                                           itemsets  length
# 0  0.545055                      (Muôn Kiếp Nhân Sinh - Tập 1)       1
# 1  0.208791                        (Hành Trình Về Phương Đông)       1
# 2  0.173626                                     (Đắc Nhân Tâm)       1
# 3  0.162637  (Hành Trình Về Phương Đông, Muôn Kiếp Nhân Sin...       2
# 4  0.127473                                  (Làm Gì Trước 30)       1
# 5  0.120879                                (Dấu Chân Trên Cát)       1
# 6  0.118681                    (Thái độ quyết định thành công)       1
# 7  0.107692                     (Giỏi Giao Tiếp Dễ Thành Công)       1
# 8  0.103297   (Dấu Chân Trên Cát, Muôn Kiếp Nhân Sinh - Tập 1)       2

# %%
list_userid3 = get_list(order,'VIP','bill_type')
new_frequent3 = mb_frequent(basket,list_userid2,min_sup = 0.1)
new_frequent3
# Out:
#     support                                           itemsets  length
# 0  0.545055                      (Muôn Kiếp Nhân Sinh - Tập 1)       1
# 1  0.208791                        (Hành Trình Về Phương Đông)       1
# 2  0.173626                                     (Đắc Nhân Tâm)       1
# 3  0.162637  (Hành Trình Về Phương Đông, Muôn Kiếp Nhân Sin...       2
# 4  0.127473                                  (Làm Gì Trước 30)       1
# 5  0.120879                                (Dấu Chân Trên Cát)       1
# 6  0.118681                    (Thái độ quyết định thành công)       1
# 7  0.107692                     (Giỏi Giao Tiếp Dễ Thành Công)       1
# 8  0.103297   (Dấu Chân Trên Cát, Muôn Kiếp Nhân Sinh - Tập 1)       2

# %%
basket_paid = basket[basket.index.isin(list(hv_paid.userID))]
basket_paid
# Out:
# playlist_name   Bé Gấu 5 Tuổi Đã Dạy Tôi Những Gì   Kinh Vu Lan Bồn  \
# userID
# 40843                                           0                 0
# 41003                                           0                 0
# 41014                                           0                 0
# 41057                                           0                 0
# 41094                                           0                 0
# ...                                           ...               ...
# 106309                                          0                 0
# 106371                                          0                 0
# 106406                                          0                 0
# 106480                                          0                 0
# 106570                                          0                 0
#
# playlist_name   Triết - 101 Đoá Sen   Triết - Trí Tuệ Hoan Hỷ  \
# userID
# 40843                             0                         0
# 41003                             0                         0
# 41014                             0                         0
# 41057                             0                         0
# 41094                             0                         0
# ...                             ...                       ...
# 106309                            0                         0
# 106371                            0                         0
# 106406                            0                         0
# 106480                            0                         0
# 106570                            0                         0
#
# playlist_name   Triết - Đức Phật Thuyết Giảng Về Tánh Không Và Vô Ngã  \
# userID
# 40843                                                          0
# 41003                                                          0
# 41014                                                          0
# 41057                                                          0
# 41094                                                          0
# ...                                                          ...
# 106309                                                         0
# 106371                                                         0
# 106406                                                         0
# 106480                                                         0
# 106570                                                         0
#
# playlist_name   Đồng Dao Cho Bé 2   Đồng Dao Cho Bé 3  "Phúc" Nuôi Dạy Con  \
# userID
# 40843                           0                   0                    0
# 41003                           0                   0                    0
# 41014                           0                   0                    0
# 41057                           0                   0                    0
# 41094                           1                   1                    0
# ...                           ...                 ...                  ...
# 106309                          0                   0                    0
# 106371                          0                   0                    0
# 106406                          0                   0                    0
# 106480                          0                   0                    0
# 106570                          0                   0                    0
#
# playlist_name  #HOHATUTA Học hành và trưởng thành cùng Hà Anh  \
# userID
# 40843                                                       0
# 41003                                                       0
# 41014                                                       0
# 41057                                                       0
# 41094                                                       0
# ...                                                       ...
# 106309                                                      0
# 106371                                                      0
# 106406                                                      0
# 106480                                                      0
# 106570                                                      0
#
# playlist_name  10 Bí Quyết Của Các MC, Diễn Giả  ...  \
# userID                                           ...
# 40843                                         0  ...
# 41003                                         0  ...
# 41014                                         0  ...
# 41057                                         0  ...
# 41094                                         0  ...
# ...                                         ...  ...
# 106309                                        0  ...
# 106371                                        0  ...
# 106406                                        0  ...
# 106480                                        0  ...
# 106570                                        0  ...
#
# playlist_name  Độc Đáo TV - Tin tức hàng ngày  \
# userID
# 40843                                       0
# 41003                                       0
# 41014                                       0
# 41057                                       0
# 41094                                       0
# ...                                       ...
# 106309                                      0
# 106371                                      0
# 106406                                      0
# 106480                                      0
# 106570                                      0
#
# playlist_name  Đội Thiếu Niên Du Kích Thành Huế  \
# userID
# 40843                                         0
# 41003                                         0
# 41014                                         0
# 41057                                         1
# 41094                                         0
# ...                                         ...
# 106309                                        0
# 106371                                        0
# 106406                                        0
# 106480                                        0
# 106570                                        0
#
# playlist_name  Đội Thiếu Niên Du Kích Đình Bảng  \
# userID
# 40843                                         0
# 41003                                         0
# 41014                                         0
# 41057                                         0
# 41094                                         0
# ...                                         ...
# 106309                                        0
# 106371                                        0
# 106406                                        0
# 106480                                        0
# 106570                                        0
#
# playlist_name  Đội Thiếu Niên Tình Báo Bát Sắt  Đột Phá Tư Duy Thương Hiệu  \
# userID
# 40843                                        0                           0
# 41003                                        0                           0
# 41014                                        0                           0
# 41057                                        0                           1
# 41094                                        0                           0
# ...                                        ...                         ...
# 106309                                       0                           0
# 106371                                       0                           0
# 106406                                       0                           0
# 106480                                       0                           0
# 106570                                       0                           0
#
# playlist_name  Đừng Bao Giờ Từ Bỏ Ước Mơ  Đừng Mơ Sói Ạ !  Đừng để mất bò  \
# userID
# 40843                                  0                0               0
# 41003                                  0                0               1
# 41014                                  0                0               0
# 41057                                  0                0               0
# 41094                                  1                0               0
# ...                                  ...              ...             ...
# 106309                                 0                0               0
# 106371                                 0                0               0
# 106406                                 0                0               0
# 106480                                 0                0               0
# 106570                                 0                0               0
#
# playlist_name  Ưu Đãi Đặc Biệt  Ứng Dụng Thành Công NLP
# userID
# 40843                        0                        0
# 41003                        0                        0
# 41014                        0                        0
# 41057                        0                        0
# 41094                        0                        1
# ...                        ...                      ...
# 106309                       0                        0
# 106371                       0                        0
# 106406                       0                        0
# 106480                       0                        0
# 106570                       0                        0
#
# [1594 rows x 1280 columns]

# %%
# chỉ lấy user nào nghe từ 2 nhóm trở lên
basket_paid = basket_paid[(basket_paid >0).sum(axis=1) >=2]
basket_paid
# Out:
# playlist_name   Bé Gấu 5 Tuổi Đã Dạy Tôi Những Gì   Kinh Vu Lan Bồn  \
# userID
# 40843                                           0                 0
# 41003                                           0                 0
# 41014                                           0                 0
# 41057                                           0                 0
# 41094                                           0                 0
# ...                                           ...               ...
# 105688                                          0                 0
# 105731                                          0                 0
# 105759                                          0                 0
# 106309                                          0                 0
# 106480                                          0                 0
#
# playlist_name   Triết - 101 Đoá Sen   Triết - Trí Tuệ Hoan Hỷ  \
# userID
# 40843                             0                         0
# 41003                             0                         0
# 41014                             0                         0
# 41057                             0                         0
# 41094                             0                         0
# ...                             ...                       ...
# 105688                            0                         0
# 105731                            0                         0
# 105759                            0                         0
# 106309                            0                         0
# 106480                            0                         0
#
# playlist_name   Triết - Đức Phật Thuyết Giảng Về Tánh Không Và Vô Ngã  \
# userID
# 40843                                                          0
# 41003                                                          0
# 41014                                                          0
# 41057                                                          0
# 41094                                                          0
# ...                                                          ...
# 105688                                                         0
# 105731                                                         0
# 105759                                                         0
# 106309                                                         0
# 106480                                                         0
#
# playlist_name   Đồng Dao Cho Bé 2   Đồng Dao Cho Bé 3  "Phúc" Nuôi Dạy Con  \
# userID
# 40843                           0                   0                    0
# 41003                           0                   0                    0
# 41014                           0                   0                    0
# 41057                           0                   0                    0
# 41094                           1                   1                    0
# ...                           ...                 ...                  ...
# 105688                          0                   0                    0
# 105731                          0                   0                    0
# 105759                          0                   0                    0
# 106309                          0                   0                    0
# 106480                          0                   0                    0
#
# playlist_name  #HOHATUTA Học hành và trưởng thành cùng Hà Anh  \
# userID
# 40843                                                       0
# 41003                                                       0
# 41014                                                       0
# 41057                                                       0
# 41094                                                       0
# ...                                                       ...
# 105688                                                      0
# 105731                                                      0
# 105759                                                      0
# 106309                                                      0
# 106480                                                      0
#
# playlist_name  10 Bí Quyết Của Các MC, Diễn Giả  ...  \
# userID                                           ...
# 40843                                         0  ...
# 41003                                         0  ...
# 41014                                         0  ...
# 41057                                         0  ...
# 41094                                         0  ...
# ...                                         ...  ...
# 105688                                        0  ...
# 105731                                        0  ...
# 105759                                        0  ...
# 106309                                        0  ...
# 106480                                        0  ...
#
# playlist_name  Độc Đáo TV - Tin tức hàng ngày  \
# userID
# 40843                                       0
# 41003                                       0
# 41014                                       0
# 41057                                       0
# 41094                                       0
# ...                                       ...
# 105688                                      0
# 105731                                      0
# 105759                                      0
# 106309                                      0
# 106480                                      0
#
# playlist_name  Đội Thiếu Niên Du Kích Thành Huế  \
# userID
# 40843                                         0
# 41003                                         0
# 41014                                         0
# 41057                                         1
# 41094                                         0
# ...                                         ...
# 105688                                        0
# 105731                                        0
# 105759                                        0
# 106309                                        0
# 106480                                        0
#
# playlist_name  Đội Thiếu Niên Du Kích Đình Bảng  \
# userID
# 40843                                         0
# 41003                                         0
# 41014                                         0
# 41057                                         0
# 41094                                         0
# ...                                         ...
# 105688                                        0
# 105731                                        0
# 105759                                        0
# 106309                                        0
# 106480                                        0
#
# playlist_name  Đội Thiếu Niên Tình Báo Bát Sắt  Đột Phá Tư Duy Thương Hiệu  \
# userID
# 40843                                        0                           0
# 41003                                        0                           0
# 41014                                        0                           0
# 41057                                        0                           1
# 41094                                        0                           0
# ...                                        ...                         ...
# 105688                                       0                           0
# 105731                                       0                           0
# 105759                                       0                           0
# 106309                                       0                           0
# 106480                                       0                           0
#
# playlist_name  Đừng Bao Giờ Từ Bỏ Ước Mơ  Đừng Mơ Sói Ạ !  Đừng để mất bò  \
# userID
# 40843                                  0                0               0
# 41003                                  0                0               1
# 41014                                  0                0               0
# 41057                                  0                0               0
# 41094                                  1                0               0
# ...                                  ...              ...             ...
# 105688                                 0                0               0
# 105731                                 0                0               0
# 105759                                 0                0               0
# 106309                                 0                0               0
# 106480                                 0                0               0
#
# playlist_name  Ưu Đãi Đặc Biệt  Ứng Dụng Thành Công NLP
# userID
# 40843                        0                        0
# 41003                        0                        0
# 41014                        0                        0
# 41057                        0                        0
# 41094                        0                        1
# ...                        ...                      ...
# 105688                       0                        0
# 105731                       0                        0
# 105759                       0                        0
# 106309                       0                        0
# 106480                       0                        0
#
# [1407 rows x 1280 columns]

# %%
list(hv_paid[hv_paid.main_clustering_description == 'New Paid Users'].userID)
# Out:
# [40843,
#  41955,
#  44112,
#  45239,
#  45647,
#  46326,
#  46671,
#  48855,
#  49436,
#  49644,
#  49673,
#  51211,
#  51362,
#  51937,
#  53056,
#  54123,
#  54144,
#  54406,
#  54825,
#  55615,
#  55924,
#  56006,
#  56250,
#  56536,
#  57235,
#  58105,
#  59064,
#  59264,
#  60692,
#  61899,
#  62158,
#  62417,
#  62561,
#  62698,
#  62749,
#  63263,
#  63387,
#  63496,
#  64254,
#  64305,
#  64684,
#  65712,
#  66006,
#  66870,
#  67528,
#  67730,
#  68059,
#  69445,
#  70663,
#  70795,
#  70967,
#  71032,
#  71519,
#  71820,
#  73544,
#  75266,
#  75621,
#  75762,
#  77322,
#  77331,
#  77530,
#  78330,
#  78480,
#  78618,
#  79121,
#  79206,
#  79566,
#  79899,
#  80298,
#  80772,
#  80946,
#  81050,
#  82769,
#  82834,
#  82999,
#  83342,
#  83838,
#  84146,
#  84525,
#  85771,
#  86133,
#  86151,
#  86173,
#  86408,
#  87097,
#  87158,
#  87433,
#  87658,
#  87820,
#  87912,
#  88127,
#  88982,
#  89186,
#  89552,
#  89619,
#  89634,
#  90561,
#  90791,
#  90965,
#  91149,
#  91193,
#  91383,
#  91521,
#  91533,
#  91758,
#  91909,
#  93858,
#  94405,
#  94441,
#  94576,
#  94851,
#  94945,
#  95187,
#  95318,
#  95362,
#  95451,
#  95512,
#  95733,
#  95857,
#  96080,
#  96171,
#  96303,
#  96342,
#  96627,
#  96673,
#  97307,
#  97439,
#  97582,
#  98069,
#  98165,
#  98445,
#  98613,
#  98614,
#  98955,
#  99015,
#  99119,
#  99816,
#  100097,
#  100621,
#  100910,
#  101007,
#  101093,
#  101113,
#  101178,
#  101467,
#  101548,
#  101560,
#  101704,
#  102341,
#  102503,
#  103000,
#  103431,
#  103932,
#  105240,
#  105480,
#  105793,
#  105795,
#  105926,
#  106019,
#  106057,
#  51191,
#  51244,
#  56069,
#  86329,
#  52155,
#  60905,
#  61666,
#  72199,
#  72971,
#  73782,
#  74743,
#  79640,
#  79717,
#  79870,
#  81221,
#  81762,
#  83615,
#  84758,
#  87388,
#  87695,
#  87895,
#  88163,
#  88469,
#  89679,
#  90676,
#  91136,
#  91610,
#  91832,
#  92398,
#  93703,
#  93898,
#  93988,
#  94600,
#  94609,
#  94675,
#  94714,
#  95066,
#  95364,
#  95940,
#  96374,
#  97231,
#  97603,
#  98049,
#  98156,
#  98737,
#  98797,
#  99041,
#  100747,
#  101059,
#  101224,
#  101327,
#  101372,
#  101508,
#  101846,
#  102145,
#  103450,
#  105267,
#  105432,
#  105591,
#  105688,
#  105731,
#  105850,
#  106182,
#  106570,
#  41014,
#  42943,
#  43753,
#  44881,
#  44951,
#  45215,
#  45234,
#  45250,
#  45471,
#  45504,
#  45628,
#  45639,
#  45728,
#  45850,
#  45991,
#  46069,
#  46118,
#  46135,
#  46136,
#  46219,
#  46349,
#  46427,
#  46458,
#  46606,
#  46693,
#  46698,
#  46733,
#  46824,
#  46831,
#  46899,
#  47016,
#  47307,
#  47308,
#  47461,
#  47584,
#  47833,
#  47931,
#  47973,
#  48864,
#  48941,
#  49116,
#  49126,
#  49200,
#  49357,
#  49370,
#  49512,
#  49618,
#  49833,
#  49880,
#  50090,
#  50141,
#  50205,
#  50261,
#  50465,
#  50565,
#  50599,
#  50823,
#  50963,
#  51173,
#  51256,
#  51382,
#  51713,
#  52091,
#  52471,
#  52502,
#  52605,
#  53077,
#  53093,
#  53249,
#  53301,
#  53507,
#  53728,
#  53806,
#  54393,
#  54423,
#  54570,
#  54916,
#  55091,
#  55353,
#  55546,
#  55609,
#  55830,
#  55882,
#  55918,
#  56043,
#  56249,
#  56766,
#  56980,
#  57008,
#  57016,
#  57582,
#  57605,
#  57730,
#  57762,
#  57864,
#  57982,
#  57989,
#  58010,
#  58131,
#  58490,
#  58577,
#  58723,
#  58858,
#  58915,
#  58922,
#  59024,
#  59034,
#  59497,
#  59641,
#  59877,
#  60157,
#  60702,
#  60830,
#  60854,
#  60867,
#  61668,
#  61790,
#  61878,
#  62610,
#  62664,
#  62878,
#  63018,
#  64372,
#  64393,
#  64493,
#  64630,
#  64827,
#  65017,
#  65286,
#  65379,
#  65772,
#  66523,
#  66986,
#  67119,
#  67200,
#  67585,
#  68109,
#  68536,
#  69245,
#  69309,
#  69388,
#  69525,
#  71558,
#  72135,
#  73723,
#  74110,
#  74233,
#  74904,
#  75175,
#  75525,
#  76596,
#  76889,
#  77408,
#  77642,
#  80070,
#  80116,
#  80262,
#  80330,
#  80725,
#  80959,
#  81193,
#  82029,
#  83749,
#  84256,
#  86337,
#  86785,
#  87144,
#  87288,
#  87298,
#  87809,
#  88214,
#  88402,
#  89594,
#  90396,
#  91012,
#  91156,
#  92047,
#  92395,
#  93173,
#  93525,
#  93785,
#  94774,
#  94790,
#  95789,
#  96237,
#  96378,
#  96495,
#  97655,
#  97822,
#  97903,
#  99780,
#  99831,
#  100158,
#  100618,
#  101308,
#  102442,
#  103263,
#  103413,
#  45214,
#  76508]

# %%
# 'Loyal Users','Potential Users
new_paid_frequent = mb_frequent(basket_paid,'Potential Users',min_sup = 0.1)
new_paid_frequent
# Out:
#      support                                           itemsets  length
# 0   0.647458                      (Muôn Kiếp Nhân Sinh - Tập 1)       1
# 1   0.289831                        (Hành Trình Về Phương Đông)       1
# 2   0.233898  (Hành Trình Về Phương Đông, Muôn Kiếp Nhân Sin...       2
# 3   0.211864                                     (Đắc Nhân Tâm)       1
# 4   0.157627                                (Dấu Chân Trên Cát)       1
# 5   0.149153                       (Vị Tu Sĩ Bán Chiếc Ferrari)       1
# 6   0.137288                    (Thái độ quyết định thành công)       1
# 7   0.135593        (Đắc Nhân Tâm, Muôn Kiếp Nhân Sinh - Tập 1)       2
# 8   0.133898   (Dấu Chân Trên Cát, Muôn Kiếp Nhân Sinh - Tập 1)       2
# 9   0.125424                        (Minh Triết Trong Đời Sống)       1
# 10  0.125424  (Vị Tu Sĩ Bán Chiếc Ferrari, Muôn Kiếp Nhân Si...       2
# 11  0.120339                               (Trở về từ xứ tuyết)       1
# 12  0.106780  (Minh Triết Trong Đời Sống, Muôn Kiếp Nhân Sin...       2
# 13  0.106780  (Trở về từ xứ tuyết, Muôn Kiếp Nhân Sinh - Tập 1)       2

# %%
frequent_paid = apriori(basket_paid, min_support = 0.1,
                        use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)
frequent_paid['length'] = frequent_paid['itemsets'].apply(lambda x:len(x))
frequent_paid
# Out:
#      support                                           itemsets  length
# 0   0.660981                      (Muôn Kiếp Nhân Sinh - Tập 1)       1
# 1   0.326226                        (Hành Trình Về Phương Đông)       1
# 2   0.278607  (Hành Trình Về Phương Đông, Muôn Kiếp Nhân Sin...       2
# 3   0.226724                                     (Đắc Nhân Tâm)       1
# 4   0.210377                                (Dấu Chân Trên Cát)       1
# 5   0.190476   (Dấu Chân Trên Cát, Muôn Kiếp Nhân Sinh - Tập 1)       2
# 6   0.175551                        (Minh Triết Trong Đời Sống)       1
# 7   0.165601                    (Thái độ quyết định thành công)       1
# 8   0.158493                       (Vị Tu Sĩ Bán Chiếc Ferrari)       1
# 9   0.155650                               (Trở về từ xứ tuyết)       1
# 10  0.153518  (Minh Triết Trong Đời Sống, Muôn Kiếp Nhân Sin...       2
# 11  0.142146  (Trở về từ xứ tuyết, Muôn Kiếp Nhân Sinh - Tập 1)       2
# 12  0.138593        (Đắc Nhân Tâm, Muôn Kiếp Nhân Sinh - Tập 1)       2
# 13  0.133618  (Vị Tu Sĩ Bán Chiếc Ferrari, Muôn Kiếp Nhân Si...       2
# 14  0.125800     (Hành Trình Về Phương Đông, Dấu Chân Trên Cát)       2
# 15  0.120824  (Hành Trình Về Phương Đông, Dấu Chân Trên Cát,...       3
# 16  0.117982                     (Giỏi Giao Tiếp Dễ Thành Công)       1
# 17  0.116560                  (Trời Tính Không Bằng Trời Tính )       1
# 18  0.110163                      (Nghìn Lẻ Một Đêm - 1001 đêm)       1
# 19  0.109453               (Huyền thuật và các đạo sĩ Tây Tạng)       1
# 20  0.109453  (Thái độ quyết định thành công, Muôn Kiếp Nhân...       2
# 21  0.104478                               (Trở Về Từ Cõi Sáng)       1
# 22  0.101635  (Huyền thuật và các đạo sĩ Tây Tạng, Muôn Kiếp...       2

# %%
final_paid = association_rules(frequent_paid, metric='lift',
                 min_threshold=1).sort_values('lift',ascending=False).reset_index(drop=True)
final_paid
# Out:
#                                           antecedents  \
# 0                                 (Dấu Chân Trên Cát)
# 1   (Hành Trình Về Phương Đông, Muôn Kiếp Nhân Sin...
# 2    (Dấu Chân Trên Cát, Muôn Kiếp Nhân Sinh - Tập 1)
# 3                         (Hành Trình Về Phương Đông)
# 4                                 (Dấu Chân Trên Cát)
# 5                         (Hành Trình Về Phương Đông)
# 6                       (Muôn Kiếp Nhân Sinh - Tập 1)
# 7      (Hành Trình Về Phương Đông, Dấu Chân Trên Cát)
# 8                       (Muôn Kiếp Nhân Sinh - Tập 1)
# 9                (Huyền thuật và các đạo sĩ Tây Tạng)
# 10                               (Trở về từ xứ tuyết)
# 11                      (Muôn Kiếp Nhân Sinh - Tập 1)
# 12                      (Muôn Kiếp Nhân Sinh - Tập 1)
# 13                                (Dấu Chân Trên Cát)
# 14                      (Muôn Kiếp Nhân Sinh - Tập 1)
# 15                        (Minh Triết Trong Đời Sống)
# 16                      (Muôn Kiếp Nhân Sinh - Tập 1)
# 17                        (Hành Trình Về Phương Đông)
# 18                       (Vị Tu Sĩ Bán Chiếc Ferrari)
# 19                      (Muôn Kiếp Nhân Sinh - Tập 1)
#
#                                           consequents  antecedent support  \
# 0   (Hành Trình Về Phương Đông, Muôn Kiếp Nhân Sin...            0.210377
# 1                                 (Dấu Chân Trên Cát)            0.278607
# 2                         (Hành Trình Về Phương Đông)            0.190476
# 3    (Dấu Chân Trên Cát, Muôn Kiếp Nhân Sinh - Tập 1)            0.326226
# 4                         (Hành Trình Về Phương Đông)            0.210377
# 5                                 (Dấu Chân Trên Cát)            0.326226
# 6      (Hành Trình Về Phương Đông, Dấu Chân Trên Cát)            0.660981
# 7                       (Muôn Kiếp Nhân Sinh - Tập 1)            0.125800
# 8                (Huyền thuật và các đạo sĩ Tây Tạng)            0.660981
# 9                       (Muôn Kiếp Nhân Sinh - Tập 1)            0.109453
# 10                      (Muôn Kiếp Nhân Sinh - Tập 1)            0.155650
# 11                               (Trở về từ xứ tuyết)            0.660981
# 12                                (Dấu Chân Trên Cát)            0.660981
# 13                      (Muôn Kiếp Nhân Sinh - Tập 1)            0.210377
# 14                        (Minh Triết Trong Đời Sống)            0.660981
# 15                      (Muôn Kiếp Nhân Sinh - Tập 1)            0.175551
# 16                        (Hành Trình Về Phương Đông)            0.660981
# 17                      (Muôn Kiếp Nhân Sinh - Tập 1)            0.326226
# 18                      (Muôn Kiếp Nhân Sinh - Tập 1)            0.158493
# 19                       (Vị Tu Sĩ Bán Chiếc Ferrari)            0.660981
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.278607  0.120824    0.574324  2.061414  0.062212    1.694701
# 1             0.210377  0.120824    0.433673  2.061414  0.062212    1.394290
# 2             0.326226  0.120824    0.634328  1.944444  0.058686    1.842566
# 3             0.190476  0.120824    0.370370  1.944444  0.058686    1.285714
# 4             0.326226  0.125800    0.597973  1.833002  0.057169    1.675942
# 5             0.210377  0.125800    0.385621  1.833002  0.057169    1.285238
# 6             0.125800  0.120824    0.182796  1.453071  0.037673    1.069745
# 7             0.660981  0.120824    0.960452  1.453071  0.037673    8.572342
# 8             0.109453  0.101635    0.153763  1.404839  0.029289    1.052362
# 9             0.660981  0.101635    0.928571  1.404839  0.029289    4.746269
# 10            0.660981  0.142146    0.913242  1.381647  0.039265    3.907642
# 11            0.155650  0.142146    0.215054  1.381647  0.039265    1.075678
# 12            0.210377  0.190476    0.288172  1.369791  0.051421    1.109290
# 13            0.660981  0.190476    0.905405  1.369791  0.051421    3.583917
# 14            0.175551  0.153518    0.232258  1.323025  0.037482    1.073862
# 15            0.660981  0.153518    0.874494  1.323025  0.037482    2.701217
# 16            0.326226  0.278607    0.421505  1.292066  0.062978    1.164702
# 17            0.660981  0.278607    0.854031  1.292066  0.062978    2.322534
# 18            0.660981  0.133618    0.843049  1.275452  0.028857    2.160037
# 19            0.158493  0.133618    0.202151  1.275452  0.028857    1.054719
