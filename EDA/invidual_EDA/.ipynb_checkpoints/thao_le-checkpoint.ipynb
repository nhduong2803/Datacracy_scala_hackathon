# %%
import pandas as pd
import numpy as np

# %%
cd C:\Users\USER\OneDrive\Documents\GitHub\Datacracy_scala_hackathon\data
# Out:
# C:\Users\USER\OneDrive\Documents\GitHub\Datacracy_scala_hackathon\data

# %%
user = pd.read_csv('user_processed.csv',sep=',')
listening = pd.read_csv('listening_processed.csv',sep=',')
order = pd.read_csv('order_processed.csv',sep=',')
clustering = pd.read_csv('clustering_processed.csv',sep=',')

# %%
order = order.rename(columns = {"OrderID (PK)": "oderID", "Transaction Date" : "transaction_date","UserID (FK)" : "userID", "Bill Type": "bill_type", "Total Amount": "total_amount" })
clustering = clustering.rename(columns = {"User_ID (FK)": "userID", "Type_user": "type_user", "MainCluster_ID" : "main_cluseringID", "MainCluster_Description" : "main_clustering_description"})
listening = listening.rename(columns = {"PlaylistID (PK)": "playlistID", "Playlist Name":"playlist_name", "Category":"cat", "Sub Category" :"sub_cat", "Playlist Type" :"palylist_type","Playlist Duration (min)": "playlist_duration","Actual Duration (min)":"actual_duation","UserID (FK)":"userID", "Listening Time":"listening_time", "Listening Date" :"listening_date", "Listening Datetime":"listening_datetime"})
user = user.rename(columns = {"UserID (PK)":"userID", "VIP hay Free":"user_type", "Gender":"gender", "Year of Birth":"year_of_birth","Age Range": "age_range", "Age":"age", "Region": "region","Operation Systems":"operation_system","Registration Date":"registration_date", "Total Listerning":"total_listening", "Total Listening Time (Min)":"total_listening_time",   })

# %%
user.head()
# Out:
#    userID user_type gender  year_of_birth       age_range   age region  \
# 0   86229      free   male            NaN  No information   NaN     VN
# 1   48053      free   male         1995.0         25 - 34  26.0     VN
# 2   46340      free   male         1988.0         25 - 34  33.0     VN
# 3   66659      free   male         1992.0         25 - 34  29.0     VN
# 4   59396      free   male            NaN  No information   NaN     VN
#
#   operation_system registration_date  total_listening  total_listening_time
# 0          android        2020-11-27              218                4151.3
# 1              ios        2020-08-24               19                 278.6
# 2          website        2020-08-19               28                 170.5
# 3          website        2020-10-22              345                6721.4
# 4          android        2020-09-29               23                  52.5

# %%
len(set(list(user['userID'])))
# Out:
# 66146

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66146 entries, 0 to 66145
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   userID                66146 non-null  int64
#  1   user_type             66146 non-null  object
#  2   gender                66146 non-null  object
#  3   year_of_birth         9745 non-null   float64
#  4   age_range             66146 non-null  object
#  5   age                   9745 non-null   float64
#  6   region                66146 non-null  object
#  7   operation_system      50320 non-null  object
#  8   registration_date     66146 non-null  object
#  9   total_listening       66146 non-null  int64
#  10  total_listening_time  66146 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 5.6+ MB

# %%
listening.head()
# Out:
#    playlistID                                      playlist_name  \
# 0        4529                      Dạy Tiếng Anh Cho Trẻ Mầm Non
# 1        4577  Tư Duy Tích Cực - Bạn Là Những Gì Bạn Nghĩ (Nh...
# 2        4169  50 thiên thần của bạn: Giải phóng bản thân khỏ...
# 3        4581                    [Sách Tóm Tắt] Đọc Vị Bất Kỳ Ai
# 4        4577  Tư Duy Tích Cực - Bạn Là Những Gì Bạn Nghĩ (Nh...
#
#             cat        sub_cat palylist_type  playlist_duration  \
# 0       Podcast  Học ngoại ngữ          free               44.9
# 1      Sách nói      Hạnh phúc           vip               79.8
# 2      Sách nói       Tâm linh           vip              324.8
# 3  Sách tóm tắt   Sách tóm tắt          free               24.8
# 4      Sách nói      Hạnh phúc           vip               79.8
#
#    actual_duation  userID listening_time listening_date   listening_datetime  \
# 0             0.1   82846       06:05:00     03-12-2020  2020-12-03 06:05:00
# 1            15.9   56112       12:49:00     30-10-2020  2020-10-30 12:49:00
# 2             6.8   94362       00:17:00     15-12-2020  2020-12-15 00:17:00
# 3             2.1   85469       23:09:00     29-11-2020  2020-11-29 23:09:00
# 4            19.0   70171       21:09:00     06-12-2020  2020-12-06 21:09:00
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
order
# Out:
#       oderID transaction_date  userID bill_type  total_amount
# 0       6706       2020-08-16   44822       VIP        199000
# 1       6998       2020-08-23   47128       VIP        199000
# 2       6927       2020-08-21   47134       VIP        199000
# 3       7054       2020-08-25   45972       VIP        199000
# 4       6929       2020-08-21   43556       VIP        199000
# ...      ...              ...     ...       ...           ...
# 3570   13029       2020-12-31  106406       VIP        199000
# 3571   13027       2020-12-31  102442       VIP        599000
# 3572   13038       2020-12-31   98510       VIP        499000
# 3573   13032       2020-12-31  106480       VIP        159000
# 3574   13040       2020-12-31   65210       VIP        159000
#
# [3575 rows x 5 columns]

# %%
order.nunique()
# Out:
# oderID              3376
# transaction_date     163
# userID              2638
# bill_type              3
# total_amount          19
# dtype: int64

# %%
set(order['bill_type'])
# Out:
# {'9K', 'VIP', 'XU'}

# %%
user_spending = order.groupby(['userID']).sum('total_amount')
user_spending
# Out:
#         oderID  total_amount
# userID
# 40843     2544         27000
# 40861     7707        199000
# 41003     9599        599000
# 41014    15326        398000
# 41057     9313        599000
# ...        ...           ...
# 106773   12988        199000
# 106960   13012        159000
# 106971   13024        159000
# 106974   13018        199000
# 106981   13016        159000
#
# [2638 rows x 2 columns]

# %%
clustering.head()
# Out:
#    userID type_user  main_cluseringID main_clustering_description
# 0   40834      free                 1                 Hibernating
# 1   40854      free                 1                 Hibernating
# 2   40876      free                 1                 Hibernating
# 3   40883      free                 1                 Hibernating
# 4   40891      free                 1                 Hibernating

# %%
clustering.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27458 entries, 0 to 27457
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   userID                       27458 non-null  int64
#  1   type_user                    27458 non-null  object
#  2   main_cluseringID             27458 non-null  int64
#  3   main_clustering_description  27458 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 858.2+ KB

# %%
clustering.groupby(['type_user','main_clustering_description','main_cluseringID']).count()
# Out:
#                                                             userID
# type_user main_clustering_description     main_cluseringID
# free      Defrost                         2                   1185
#           Hibernating                     1                   3093
#           Lost active user                4                   2510
#           Loyal Users, Engaging Listeners 10                   427
#           Loyal Users, Skimming Listeners 9                    342
#           Need Attention                  3                   6196
#           New User, Skimming Listeners    5                   4256
#           New Users, Engaging Listeners   6                   4099
#           Potential, Engaging Listeners   8                   1622
#           Potential, Skimming Listeners   7                   1090
# paid      Churn App Users                 1                    387
#           Lost High-value                 4                    119
#           Lost Users                      3                    254
#           Loyal Users                     7                    552
#           Need attention                  2                    175
#           New Paid Users                  5                    424
#           Potential Users                 6                    727

# %%
clustering.groupby('type_user').count()
# Out:
#            userID  main_cluseringID  main_clustering_description
# type_user
# free        24820             24820                        24820
# paid         2638              2638                         2638

# %% [markdown]
# ### High values user:
# 1. Paid: chi trả > 199.000
# 2. Free: nghe tb tuần >=3
#
# => chọn từ clustering của nhóm

# %%
user_process = pd.merge(clustering,user, how='left',left_on='User_ID (FK)', right_on='UserID (PK)')
user_process
# Out:
#        User_ID (FK) Type_user  MainCluster_ID MainCluster_Description  \
# 0             40834      free               1             Hibernating
# 1             40854      free               1             Hibernating
# 2             40876      free               1             Hibernating
# 3             40883      free               1             Hibernating
# 4             40891      free               1             Hibernating
# ...             ...       ...             ...                     ...
# 27453         76980      paid               3              Lost Users
# 27454         78868      paid               3              Lost Users
# 27455         81001      paid               3              Lost Users
# 27456         83850      paid               3              Lost Users
# 27457         61295      paid               1         Churn App Users
#
#        UserID (PK) VIP hay Free          Gender  Year of Birth  \
# 0            40834         free  no information            NaN
# 1            40854         free          female         1999.0
# 2            40876         free  no information            NaN
# 3            40883         free  no information            NaN
# 4            40891         free  no information            NaN
# ...            ...          ...             ...            ...
# 27453        76980         free  no information            NaN
# 27454        78868         free          female         1985.0
# 27455        81001         free            male         1986.0
# 27456        83850         free          female         1985.0
# 27457        61295         free  no information            NaN
#
#             Age Range   Age Region Operation Systems Registration Date  \
# 0      No information   NaN     QT               ios        2020-07-01
# 1             18 - 24  22.0     VN           website        2020-07-01
# 2      No information   NaN     VN               ios        2020-07-01
# 3      No information   NaN     VN               ios        2020-07-01
# 4      No information   NaN     VN               ios        2020-07-01
# ...               ...   ...    ...               ...               ...
# 27453  No information   NaN     VN           android        2020-11-10
# 27454         35 - 44  36.0     VN               ios        2020-11-13
# 27455         35 - 44  35.0     QT               ios        2020-11-17
# 27456         35 - 44  36.0     VN               ios        2020-11-22
# 27457  No information   NaN     VN               ios        2020-10-05
#
#        Total Listerning  Total Listening Time (Min)
# 0                     2                         8.7
# 1                   444                     20988.0
# 2                     3                         0.8
# 3                     5                         2.9
# 4                    13                        71.5
# ...                 ...                         ...
# 27453                22                        12.7
# 27454               159                      3441.8
# 27455                61                      1441.5
# 27456                75                       842.6
# 27457                14                       268.0
#
# [27458 rows x 15 columns]

# %%
user_process_2 = pd.merge(user_process,user_spending, how='left',left_on='User_ID (FK)', right_on='UserID (FK)')
user_process_2
# Out:
#        User_ID (FK) Type_user  MainCluster_ID MainCluster_Description  \
# 0             40834      free               1             Hibernating
# 1             40854      free               1             Hibernating
# 2             40876      free               1             Hibernating
# 3             40883      free               1             Hibernating
# 4             40891      free               1             Hibernating
# ...             ...       ...             ...                     ...
# 27453         76980      paid               3              Lost Users
# 27454         78868      paid               3              Lost Users
# 27455         81001      paid               3              Lost Users
# 27456         83850      paid               3              Lost Users
# 27457         61295      paid               1         Churn App Users
#
#        UserID (PK) VIP hay Free          Gender  Year of Birth  \
# 0            40834         free  no information            NaN
# 1            40854         free          female         1999.0
# 2            40876         free  no information            NaN
# 3            40883         free  no information            NaN
# 4            40891         free  no information            NaN
# ...            ...          ...             ...            ...
# 27453        76980         free  no information            NaN
# 27454        78868         free          female         1985.0
# 27455        81001         free            male         1986.0
# 27456        83850         free          female         1985.0
# 27457        61295         free  no information            NaN
#
#             Age Range   Age Region Operation Systems Registration Date  \
# 0      No information   NaN     QT               ios        2020-07-01
# 1             18 - 24  22.0     VN           website        2020-07-01
# 2      No information   NaN     VN               ios        2020-07-01
# 3      No information   NaN     VN               ios        2020-07-01
# 4      No information   NaN     VN               ios        2020-07-01
# ...               ...   ...    ...               ...               ...
# 27453  No information   NaN     VN           android        2020-11-10
# 27454         35 - 44  36.0     VN               ios        2020-11-13
# 27455         35 - 44  35.0     QT               ios        2020-11-17
# 27456         35 - 44  36.0     VN               ios        2020-11-22
# 27457  No information   NaN     VN               ios        2020-10-05
#
#        Total Listerning  Total Listening Time (Min)  OrderID (PK)  \
# 0                     2                         8.7           NaN
# 1                   444                     20988.0           NaN
# 2                     3                         0.8           NaN
# 3                     5                         2.9           NaN
# 4                    13                        71.5           NaN
# ...                 ...                         ...           ...
# 27453                22                        12.7       10131.0
# 27454               159                      3441.8       10588.0
# 27455                61                      1441.5        1790.0
# 27456                75                       842.6       10703.0
# 27457                14                       268.0        8760.0
#
#        Total Amount
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 27453      199000.0
# 27454      199000.0
# 27455      298000.0
# 27456      159000.0
# 27457      199000.0
#
# [27458 rows x 17 columns]

# %%
# tao bảng user số lượng nghe, thời gian nghe
listening.groupby('UserID (FK)').count()
# Out:
#              PlaylistID (PK)  Playlist Name  Category  Sub Category  \
# UserID (FK)
# 40834                      2              2         2             2
# 40835                      5              5         5             5
# 40839                     60             60        60            60
# 40840                    491            491       491           491
# 40842                     67             67        67            67
# ...                      ...            ...       ...           ...
# 107206                     2              2         2             2
# 107209                     4              4         4             4
# 107212                     1              1         1             1
# 107217                     5              5         5             5
# 107219                     6              6         6             6
#
#              Playlist Type  Playlist Duration (min)  Actual Duration (min)  \
# UserID (FK)
# 40834                    2                        2                      2
# 40835                    5                        5                      5
# 40839                   60                       60                     60
# 40840                  491                      491                    491
# 40842                   67                       67                     67
# ...                    ...                      ...                    ...
# 107206                   2                        2                      2
# 107209                   4                        4                      4
# 107212                   1                        1                      1
# 107217                   5                        5                      5
# 107219                   6                        6                      6
#
#              Listening Time  Listening Date  Listening Datetime  Unnamed: 11
# UserID (FK)
# 40834                     2               2                   2            0
# 40835                     5               5                   5            0
# 40839                    60              60                  60            0
# 40840                   491             491                 491            0
# 40842                    67              67                  67            0
# ...                     ...             ...                 ...          ...
# 107206                    2               2                   2            0
# 107209                    4               4                   4            0
# 107212                    1               1                   1            0
# 107217                    5               5                   5            0
# 107219                    6               6                   6            0
#
# [27183 rows x 11 columns]
