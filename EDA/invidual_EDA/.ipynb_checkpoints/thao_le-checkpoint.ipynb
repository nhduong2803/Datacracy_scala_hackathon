# %%
import numpy as np
from datetime import datetime as dt
import pandas as pd, datetime as dt

# %%
cd C:\Users\USER\OneDrive\Documents\GitHub\Datacracy_scala_hackathon\data
# Out:
# C:\Users\USER\OneDrive\Documents\GitHub\Datacracy_scala_hackathon\data

# %%
user = pd.read_csv('user_processed.csv',sep=',')
listening = pd.read_csv('listening_processed.csv',sep=',')
order = pd.read_csv('order_processed.csv',sep=',')
clustering = pd.read_csv('clustering_processed.csv',sep=',')

# %%
# change column name
order = order.rename(columns = {"OrderID (PK)": "oderID", "Transaction Date" : "transaction_date","UserID (FK)" : "userID", "Bill Type": "bill_type", "Total Amount": "total_amount" })
clustering = clustering.rename(columns = {"User_ID (FK)": "userID", "Type_user": "type_user", "MainCluster_ID" : "main_cluseringID", "MainCluster_Description" : "main_clustering_description"})
listening = listening.rename(columns = {"PlaylistID (PK)": "playlistID", "Playlist Name":"playlist_name", "Category":"cat", "Sub Category" :"sub_cat", "Playlist Type" :"palylist_type","Playlist Duration (min)": "playlist_duration","Actual Duration (min)":"actual_duation","UserID (FK)":"userID", "Listening Time":"listening_time", "Listening Date" :"listening_date", "Listening Datetime":"listening_datetime"})
user = user.rename(columns = {"UserID (PK)":"userID", "VIP hay Free":"user_type", "Gender":"gender", "Year of Birth":"year_of_birth","Age Range": "age_range", "Age":"age", "Region": "region","Operation Systems":"operation_system","Registration Date":"registration_date", "Total Listerning":"total_listening", "Total Listening Time (Min)":"total_listening_time",   })

# change date time
# xu li datetime
order.transaction_date = pd.to_datetime(order['transaction_date'], format='%Y-%m-%d')
user.registration_date = pd.to_datetime(user['registration_date'], format='%Y-%m-%d')
listening.listening_datetime = pd.to_datetime(listening['listening_datetime'], format='%Y-%m-%d')

# change date by weekly
def adding_by_week(df, date_field):
    # df["by_week"] = df[[date_field]].copy()
    # df.resample('W-Mon', on=date_field).sum().reset_index().sort_values(by=date_field)
    # order1.resample('W-Mon', on='transaction_date').sum().reset_index().sort_values(by='transaction_date')
    df['by_week'] = df.apply(lambda row: row[date_field] - dt.timedelta(days=row[date_field].weekday()), axis=1)
    df = df['by_week'].groupby(df['by_week']).count()

adding_by_week(order, "transaction_date")
adding_by_week(user, "registration_date")
adding_by_week(listening, "listening_datetime")

# %%
user.head()
# Out:
#    userID user_type gender  year_of_birth       age_range   age region  \
# 0   86229      free   male            NaN  No information   NaN     VN
# 1   48053      free   male         1995.0         25 - 34  26.0     VN
# 2   46340      free   male         1988.0         25 - 34  33.0     VN
# 3   66659      free   male         1992.0         25 - 34  29.0     VN
# 4   59396      free   male            NaN  No information   NaN     VN
#
#   operation_system registration_date  total_listening  total_listening_time  \
# 0          android        2020-11-27              218                4151.3
# 1              ios        2020-08-24               19                 278.6
# 2          website        2020-08-19               28                 170.5
# 3          website        2020-10-22              345                6721.4
# 4          android        2020-09-29               23                  52.5
#
#      by_week
# 0 2020-11-23
# 1 2020-08-24
# 2 2020-08-17
# 3 2020-10-19
# 4 2020-09-28

# %% [markdown]
# ### mục tiêu là mình làm xem nhóm nào đóng góp nhiều revenue nhất
# 1. paid user: dựa vào total amount
# 2. free user: dựa vào duration, số lượt nghe

# %%
order.head()
# Out:
#    oderID transaction_date  userID bill_type  total_amount    by_week
# 0    6706       2020-08-16   44822       VIP        199000 2020-08-10
# 1    6998       2020-08-23   47128       VIP        199000 2020-08-17
# 2    6927       2020-08-21   47134       VIP        199000 2020-08-17
# 3    7054       2020-08-25   45972       VIP        199000 2020-08-24
# 4    6929       2020-08-21   43556       VIP        199000 2020-08-17

# %%
total_amount = order.groupby('userID').sum()
sum_order = total_amount.total_amount.sum()
total_amount.head()
# Out:
#         oderID  total_amount
# userID
# 40843     2544         27000
# 40861     7707        199000
# 41003     9599        599000
# 41014    15326        398000
# 41057     9313        599000

# %%
user_money = pd.merge(user,total_amount, how='left',left_on='userID', right_on='userID')
total = pd.merge(clustering,user_money, how='left',left_on='userID', right_on='userID')
total.head()
# Out:
#    userID type_user  main_cluseringID main_clustering_description user_type  \
# 0   40834      free                 1                 Hibernating      free
# 1   40854      free                 1                 Hibernating      free
# 2   40876      free                 1                 Hibernating      free
# 3   40883      free                 1                 Hibernating      free
# 4   40891      free                 1                 Hibernating      free
#
#            gender  year_of_birth       age_range   age region  \
# 0  no information            NaN  No information   NaN     QT
# 1          female         1999.0         18 - 24  22.0     VN
# 2  no information            NaN  No information   NaN     VN
# 3  no information            NaN  No information   NaN     VN
# 4  no information            NaN  No information   NaN     VN
#
#   operation_system registration_date  total_listening  total_listening_time  \
# 0              ios        2020-07-01                2                   8.7
# 1          website        2020-07-01              444               20988.0
# 2              ios        2020-07-01                3                   0.8
# 3              ios        2020-07-01                5                   2.9
# 4              ios        2020-07-01               13                  71.5
#
#      by_week  oderID  total_amount
# 0 2020-06-29     NaN           NaN
# 1 2020-06-29     NaN           NaN
# 2 2020-06-29     NaN           NaN
# 3 2020-06-29     NaN           NaN
# 4 2020-06-29     NaN           NaN

# %% [markdown]
# ### Paid contribution
# 1. by cluserter

# %%
df_paid_cluster = pd.DataFrame(total[total['type_user']=='paid'].groupby('main_clustering_description').total_amount.sum())
df_paid_cluster['%']=df_paid_cluster.total_amount/sum_order*100
df_paid_cluster.sort_values('%',ascending=False)
# Out:
#                              total_amount          %
# main_clustering_description
# Loyal Users                   262471000.0  36.638056
# Potential Users               145295000.0  20.281579
# New Paid Users                119967000.0  16.746070
# Lost High-value                70042000.0   9.777090
# Churn App Users                65260000.0   9.109576
# Lost Users                     50019000.0   6.982101
# Need attention                  3335000.0   0.465529

# %%
total_paid = total[total['type_user']=='paid']
total_paid.groupby([])
# Out:
#        userID type_user  main_cluseringID main_clustering_description  \
# 24820   40843      paid                 5              New Paid Users
# 24821   41955      paid                 5              New Paid Users
# 24822   44112      paid                 5              New Paid Users
# 24823   45239      paid                 5              New Paid Users
# 24824   45647      paid                 5              New Paid Users
# ...       ...       ...               ...                         ...
# 27453   76980      paid                 3                  Lost Users
# 27454   78868      paid                 3                  Lost Users
# 27455   81001      paid                 3                  Lost Users
# 27456   83850      paid                 3                  Lost Users
# 27457   61295      paid                 1             Churn App Users
#
#       user_type          gender  year_of_birth       age_range   age region  \
# 24820      free            male         1984.0         35 - 44  37.0     VN
# 24821      free            male            NaN  No information   NaN     VN
# 24822      free            male            NaN  No information   NaN     VN
# 24823      free            male            NaN  No information   NaN     VN
# 24824      free  no information            NaN  No information   NaN     VN
# ...         ...             ...            ...             ...   ...    ...
# 27453      free  no information            NaN  No information   NaN     VN
# 27454      free          female         1985.0         35 - 44  36.0     VN
# 27455      free            male         1986.0         35 - 44  35.0     QT
# 27456      free          female         1985.0         35 - 44  36.0     VN
# 27457      free  no information            NaN  No information   NaN     VN
#
#       operation_system registration_date  total_listening  \
# 24820              ios        2020-07-01              144
# 24821          android        2020-07-14              119
# 24822          android        2020-08-12              217
# 24823          android        2020-08-17              690
# 24824          android        2020-08-18               40
# ...                ...               ...              ...
# 27453          android        2020-11-10               22
# 27454              ios        2020-11-13              159
# 27455              ios        2020-11-17               61
# 27456              ios        2020-11-22               75
# 27457              ios        2020-10-05               14
#
#        total_listening_time    by_week   oderID  total_amount
# 24820                1563.3 2020-06-29   2544.0       27000.0
# 24821                1707.1 2020-07-13   1379.0       45000.0
# 24822                1544.0 2020-08-10   1901.0        9000.0
# 24823                5670.1 2020-08-17    668.0        9000.0
# 24824                 236.6 2020-08-17   1264.0       45000.0
# ...                     ...        ...      ...           ...
# 27453                  12.7 2020-11-09  10131.0      199000.0
# 27454                3441.8 2020-11-09  10588.0      199000.0
# 27455                1441.5 2020-11-16   1790.0      298000.0
# 27456                 842.6 2020-11-16  10703.0      159000.0
# 27457                 268.0 2020-10-05   8760.0      199000.0
#
# [2638 rows x 17 columns]

# %%
listening[listening['userID'] == 82846]
# Out:
#         playlistID                                      playlist_name  \
# 0             4529                      Dạy Tiếng Anh Cho Trẻ Mầm Non
# 904           4563                Bí Kíp Nói Tiếng Anh Như Tiếng Việt
# 3128          4563                Bí Kíp Nói Tiếng Anh Như Tiếng Việt
# 6207          4563                Bí Kíp Nói Tiếng Anh Như Tiếng Việt
# 7650          4529                      Dạy Tiếng Anh Cho Trẻ Mầm Non
# ...            ...                                                ...
# 653624        3872  [Sách Tóm Tắt] Warren Buffett - Quá Trình Hình...
# 661291        4120                      [Sách Tóm Tắt] Thế Giới Phẳng
# 687352        4563                Bí Kíp Nói Tiếng Anh Như Tiếng Việt
# 707299        4529                      Dạy Tiếng Anh Cho Trẻ Mầm Non
# 737914        4120                      [Sách Tóm Tắt] Thế Giới Phẳng
#
#                  cat        sub_cat palylist_type  playlist_duration  \
# 0            Podcast  Học ngoại ngữ          free               44.9
# 904          Podcast  Học ngoại ngữ          free              121.1
# 3128         Podcast  Học ngoại ngữ          free              121.1
# 6207         Podcast  Học ngoại ngữ          free              121.1
# 7650         Podcast  Học ngoại ngữ          free               44.9
# ...              ...            ...           ...                ...
# 653624  Sách tóm tắt   Sách tóm tắt          free               26.3
# 661291  Sách tóm tắt   Sách tóm tắt          free               30.6
# 687352       Podcast  Học ngoại ngữ          free              121.1
# 707299       Podcast  Học ngoại ngữ          free               44.9
# 737914  Sách tóm tắt   Sách tóm tắt          free               30.6
#
#         actual_duation  userID listening_time listening_date  \
# 0                  0.1   82846       06:05:00     03-12-2020
# 904                0.0   82846       21:46:00     18-11-2020
# 3128               9.2   82846       11:20:00     29-12-2020
# 6207              15.7   82846       21:46:00     25-11-2020
# 7650               1.8   82846       22:13:00     01-12-2020
# ...                ...     ...            ...            ...
# 653624            12.4   82846       21:24:00     07-12-2020
# 661291             8.2   82846       17:24:00     02-12-2020
# 687352            16.9   82846       21:46:00     03-12-2020
# 707299             0.9   82846       06:05:00     03-12-2020
# 737914             6.6   82846       17:24:00     02-12-2020
#
#          listening_datetime  Unnamed: 11
# 0       2020-12-03 06:05:00          NaN
# 904     2020-11-18 21:46:00          NaN
# 3128    2020-12-29 11:20:00          NaN
# 6207    2020-11-25 21:46:00          NaN
# 7650    2020-12-01 22:13:00          NaN
# ...                     ...          ...
# 653624  2020-12-07 21:24:00          NaN
# 661291  2020-12-02 17:24:00          NaN
# 687352  2020-12-03 21:46:00          NaN
# 707299  2020-12-03 06:05:00          NaN
# 737914  2020-12-02 17:24:00          NaN
#
# [81 rows x 12 columns]

# %%
order
# Out:
#       oderID transaction_date  userID bill_type  total_amount
# 0       6706       2020-08-16   44822       VIP        199000
# 1       6998       2020-08-23   47128       VIP        199000
# 2       6927       2020-08-21   47134       VIP        199000
# 3       7054       2020-08-25   45972       VIP        199000
# 4       6929       2020-08-21   43556       VIP        199000
# ...      ...              ...     ...       ...           ...
# 3570   13029       2020-12-31  106406       VIP        199000
# 3571   13027       2020-12-31  102442       VIP        599000
# 3572   13038       2020-12-31   98510       VIP        499000
# 3573   13032       2020-12-31  106480       VIP        159000
# 3574   13040       2020-12-31   65210       VIP        159000
#
# [3575 rows x 5 columns]

# %%
order.nunique()
# Out:
# oderID              3376
# transaction_date     163
# userID              2638
# bill_type              3
# total_amount          19
# dtype: int64

# %%
set(order['bill_type'])
# Out:
# {'9K', 'VIP', 'XU'}

# %%
user_spending = order.groupby(['userID']).sum('total_amount')
user_spending
# Out:
#         oderID  total_amount
# userID
# 40843     2544         27000
# 40861     7707        199000
# 41003     9599        599000
# 41014    15326        398000
# 41057     9313        599000
# ...        ...           ...
# 106773   12988        199000
# 106960   13012        159000
# 106971   13024        159000
# 106974   13018        199000
# 106981   13016        159000
#
# [2638 rows x 2 columns]

# %%
clustering.head()
# Out:
#    userID type_user  main_cluseringID main_clustering_description
# 0   40834      free                 1                 Hibernating
# 1   40854      free                 1                 Hibernating
# 2   40876      free                 1                 Hibernating
# 3   40883      free                 1                 Hibernating
# 4   40891      free                 1                 Hibernating

# %%
clustering.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27458 entries, 0 to 27457
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   userID                       27458 non-null  int64
#  1   type_user                    27458 non-null  object
#  2   main_cluseringID             27458 non-null  int64
#  3   main_clustering_description  27458 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 858.2+ KB

# %%
clustering.groupby(['type_user','main_clustering_description','main_cluseringID']).count()
# Out:
#                                                             userID
# type_user main_clustering_description     main_cluseringID
# free      Defrost                         2                   1185
#           Hibernating                     1                   3093
#           Lost active user                4                   2510
#           Loyal Users, Engaging Listeners 10                   427
#           Loyal Users, Skimming Listeners 9                    342
#           Need Attention                  3                   6196
#           New User, Skimming Listeners    5                   4256
#           New Users, Engaging Listeners   6                   4099
#           Potential, Engaging Listeners   8                   1622
#           Potential, Skimming Listeners   7                   1090
# paid      Churn App Users                 1                    387
#           Lost High-value                 4                    119
#           Lost Users                      3                    254
#           Loyal Users                     7                    552
#           Need attention                  2                    175
#           New Paid Users                  5                    424
#           Potential Users                 6                    727

# %%
clustering.groupby('type_user').count()
# Out:
#            userID  main_cluseringID  main_clustering_description
# type_user
# free        24820             24820                        24820
# paid         2638              2638                         2638

# %% [markdown]
# ### High values user:
# 1. Paid: chi trả > 199.000
# 2. Free: nghe tb tuần >=3
#
# => chọn từ clustering của nhóm

# %%
user_process = pd.merge(clustering,user, how='left',left_on='User_ID (FK)', right_on='UserID (PK)')
user_process
# Out:
#        User_ID (FK) Type_user  MainCluster_ID MainCluster_Description  \
# 0             40834      free               1             Hibernating
# 1             40854      free               1             Hibernating
# 2             40876      free               1             Hibernating
# 3             40883      free               1             Hibernating
# 4             40891      free               1             Hibernating
# ...             ...       ...             ...                     ...
# 27453         76980      paid               3              Lost Users
# 27454         78868      paid               3              Lost Users
# 27455         81001      paid               3              Lost Users
# 27456         83850      paid               3              Lost Users
# 27457         61295      paid               1         Churn App Users
#
#        UserID (PK) VIP hay Free          Gender  Year of Birth  \
# 0            40834         free  no information            NaN
# 1            40854         free          female         1999.0
# 2            40876         free  no information            NaN
# 3            40883         free  no information            NaN
# 4            40891         free  no information            NaN
# ...            ...          ...             ...            ...
# 27453        76980         free  no information            NaN
# 27454        78868         free          female         1985.0
# 27455        81001         free            male         1986.0
# 27456        83850         free          female         1985.0
# 27457        61295         free  no information            NaN
#
#             Age Range   Age Region Operation Systems Registration Date  \
# 0      No information   NaN     QT               ios        2020-07-01
# 1             18 - 24  22.0     VN           website        2020-07-01
# 2      No information   NaN     VN               ios        2020-07-01
# 3      No information   NaN     VN               ios        2020-07-01
# 4      No information   NaN     VN               ios        2020-07-01
# ...               ...   ...    ...               ...               ...
# 27453  No information   NaN     VN           android        2020-11-10
# 27454         35 - 44  36.0     VN               ios        2020-11-13
# 27455         35 - 44  35.0     QT               ios        2020-11-17
# 27456         35 - 44  36.0     VN               ios        2020-11-22
# 27457  No information   NaN     VN               ios        2020-10-05
#
#        Total Listerning  Total Listening Time (Min)
# 0                     2                         8.7
# 1                   444                     20988.0
# 2                     3                         0.8
# 3                     5                         2.9
# 4                    13                        71.5
# ...                 ...                         ...
# 27453                22                        12.7
# 27454               159                      3441.8
# 27455                61                      1441.5
# 27456                75                       842.6
# 27457                14                       268.0
#
# [27458 rows x 15 columns]

# %%
user_process_2 = pd.merge(user_process,user_spending, how='left',left_on='User_ID (FK)', right_on='UserID (FK)')
user_process_2
# Out:
#        User_ID (FK) Type_user  MainCluster_ID MainCluster_Description  \
# 0             40834      free               1             Hibernating
# 1             40854      free               1             Hibernating
# 2             40876      free               1             Hibernating
# 3             40883      free               1             Hibernating
# 4             40891      free               1             Hibernating
# ...             ...       ...             ...                     ...
# 27453         76980      paid               3              Lost Users
# 27454         78868      paid               3              Lost Users
# 27455         81001      paid               3              Lost Users
# 27456         83850      paid               3              Lost Users
# 27457         61295      paid               1         Churn App Users
#
#        UserID (PK) VIP hay Free          Gender  Year of Birth  \
# 0            40834         free  no information            NaN
# 1            40854         free          female         1999.0
# 2            40876         free  no information            NaN
# 3            40883         free  no information            NaN
# 4            40891         free  no information            NaN
# ...            ...          ...             ...            ...
# 27453        76980         free  no information            NaN
# 27454        78868         free          female         1985.0
# 27455        81001         free            male         1986.0
# 27456        83850         free          female         1985.0
# 27457        61295         free  no information            NaN
#
#             Age Range   Age Region Operation Systems Registration Date  \
# 0      No information   NaN     QT               ios        2020-07-01
# 1             18 - 24  22.0     VN           website        2020-07-01
# 2      No information   NaN     VN               ios        2020-07-01
# 3      No information   NaN     VN               ios        2020-07-01
# 4      No information   NaN     VN               ios        2020-07-01
# ...               ...   ...    ...               ...               ...
# 27453  No information   NaN     VN           android        2020-11-10
# 27454         35 - 44  36.0     VN               ios        2020-11-13
# 27455         35 - 44  35.0     QT               ios        2020-11-17
# 27456         35 - 44  36.0     VN               ios        2020-11-22
# 27457  No information   NaN     VN               ios        2020-10-05
#
#        Total Listerning  Total Listening Time (Min)  OrderID (PK)  \
# 0                     2                         8.7           NaN
# 1                   444                     20988.0           NaN
# 2                     3                         0.8           NaN
# 3                     5                         2.9           NaN
# 4                    13                        71.5           NaN
# ...                 ...                         ...           ...
# 27453                22                        12.7       10131.0
# 27454               159                      3441.8       10588.0
# 27455                61                      1441.5        1790.0
# 27456                75                       842.6       10703.0
# 27457                14                       268.0        8760.0
#
#        Total Amount
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 27453      199000.0
# 27454      199000.0
# 27455      298000.0
# 27456      159000.0
# 27457      199000.0
#
# [27458 rows x 17 columns]

# %%
# tao bảng user số lượng nghe, thời gian nghe
listening[listening.userID == '86229'].groupby('userID').count()
# Out:
# Empty DataFrame
# Columns: [playlistID, playlist_name, cat, sub_cat, palylist_type, playlist_duration, actual_duation, listening_time, listening_date, listening_datetime, Unnamed: 11]
# Index: []
